# %%
from sciwing.models.neural_parscit import NeuralParscit 

# instantiate an object 
neural_parscit = NeuralParscit()

# predict on a citation 
neural_parscit.predict_for_text("Calzolari, N. (1982) Towards the organization of lexical definitions on a database structure. In E. Hajicova (Ed.), COLING '82 Abstracts, Charles University, Prague, pp.61-64.")

# if you have a file of citations with one citation per line 
neural_parscit.predict_for_file("/path/to/filename")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /home/zavlyanova/Documents/00projects/Fil_rouge/fil-rouge/parscit.ipynb Cell 1' in <module>
# ----> <a href='vscode-notebook-cell:/home/zavlyanova/Documents/00projects/Fil_rouge/fil-rouge/parscit.ipynb#ch0000000?line=0'>1</a> from sciwing.models.neural_parscit import NeuralParscit
#       <a href='vscode-notebook-cell:/home/zavlyanova/Documents/00projects/Fil_rouge/fil-rouge/parscit.ipynb#ch0000000?line=2'>3</a> # instantiate an object
#       <a href='vscode-notebook-cell:/home/zavlyanova/Documents/00projects/Fil_rouge/fil-rouge/parscit.ipynb#ch0000000?line=3'>4</a> neural_parscit = NeuralParscit()
#
# File ~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/models/__init__.py:2, in <module>
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/models/__init__.py?line=0'>1</a> from sciwing.models.simpleclassifier import SimpleClassifier
# ----> <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/models/__init__.py?line=1'>2</a> from sciwing.models.rnn_seq_crf_tagger import RnnSeqCrfTagger
#
# File ~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/models/rnn_seq_crf_tagger.py:6, in <module>
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/models/rnn_seq_crf_tagger.py?line=3'>4</a> from allennlp.modules.conditional_random_field import allowed_transitions
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/models/rnn_seq_crf_tagger.py?line=4'>5</a> import torch
# ----> <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/models/rnn_seq_crf_tagger.py?line=5'>6</a> from sciwing.modules.lstm2seqencoder import Lstm2SeqEncoder
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/models/rnn_seq_crf_tagger.py?line=6'>7</a> from sciwing.data.datasets_manager import DatasetsManager
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/models/rnn_seq_crf_tagger.py?line=7'>8</a> from sciwing.data.seq_label import SeqLabel
#
# File ~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/modules/__init__.py:1, in <module>
# ----> <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/modules/__init__.py?line=0'>1</a> from sciwing.modules.embedders import *
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/modules/__init__.py?line=1'>2</a> from sciwing.modules.bow_encoder import BOW_Encoder
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/modules/__init__.py?line=2'>3</a> from sciwing.modules.lstm2vecencoder import LSTM2VecEncoder
#
# File ~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/modules/embedders/__init__.py:3, in <module>
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/modules/embedders/__init__.py?line=0'>1</a> from sciwing.modules.embedders.word_embedder import WordEmbedder
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/modules/embedders/__init__.py?line=1'>2</a> from sciwing.modules.embedders.concat_embedders import ConcatEmbedders
# ----> <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/modules/embedders/__init__.py?line=2'>3</a> from sciwing.modules.embedders.bow_elmo_embedder import BowElmoEmbedder
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/modules/embedders/__init__.py?line=3'>4</a> from sciwing.modules.embedders.bert_embedder import BertEmbedder
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/modules/embedders/__init__.py?line=4'>5</a> from sciwing.modules.embedders.char_embedder import CharEmbedder
#
# File ~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/modules/embedders/bow_elmo_embedder.py:2, in <module>
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/modules/embedders/bow_elmo_embedder.py?line=0'>1</a> import torch
# ----> <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/modules/embedders/bow_elmo_embedder.py?line=1'>2</a> from allennlp.commands.elmo import ElmoEmbedder
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/modules/embedders/bow_elmo_embedder.py?line=2'>3</a> import wasabi
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/sciwing/modules/embedders/bow_elmo_embedder.py?line=3'>4</a> from typing import List, Union
#
# File ~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/allennlp/commands/__init__.py:8, in <module>
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/allennlp/commands/__init__.py?line=4'>5</a> from overrides import overrides
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/allennlp/commands/__init__.py?line=6'>7</a> from allennlp import __version__
# ----> <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/allennlp/commands/__init__.py?line=7'>8</a> from allennlp.commands.configure import Configure
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/allennlp/commands/__init__.py?line=8'>9</a> from allennlp.commands.elmo import Elmo
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/allennlp/commands/__init__.py?line=9'>10</a> from allennlp.commands.evaluate import Evaluate
#
# File ~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/allennlp/commands/configure.py:23, in <module>
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/allennlp/commands/configure.py?line=0'>1</a> """
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/allennlp/commands/configure.py?line=1'>2</a> The ``configure`` subcommand launches a webapp that helps you
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/allennlp/commands/configure.py?line=2'>3</a> generate an AllenNLP configuration file.
#    (...)
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/allennlp/commands/configure.py?line=17'>18</a>                             additional packages to include
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/allennlp/commands/configure.py?line=18'>19</a> """
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/allennlp/commands/configure.py?line=20'>21</a> import argparse
# ---> <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/allennlp/commands/configure.py?line=22'>23</a> from flask_cors import CORS
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/allennlp/commands/configure.py?line=23'>24</a> from gevent.pywsgi import WSGIServer
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/allennlp/commands/configure.py?line=25'>26</a> from allennlp.commands.subcommand import Subcommand
#
# File ~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/__init__.py:11, in <module>
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/__init__.py?line=0'>1</a> # -*- coding: utf-8 -*-
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/__init__.py?line=1'>2</a> """
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/__init__.py?line=2'>3</a>     flask_cors
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/__init__.py?line=3'>4</a>     ~~~~
#    (...)
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/__init__.py?line=8'>9</a>     :license: MIT, see LICENSE for more details.
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/__init__.py?line=9'>10</a> """
# ---> <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/__init__.py?line=10'>11</a> from .decorator import cross_origin
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/__init__.py?line=11'>12</a> from .extension import CORS
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/__init__.py?line=12'>13</a> from .version import __version__
#
# File ~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/decorator.py:13, in <module>
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/decorator.py?line=1'>2</a> """
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/decorator.py?line=2'>3</a>     decorator
#       <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/decorator.py?line=3'>4</a>     ~~~~
#    (...)
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/decorator.py?line=9'>10</a>     :license: MIT, see LICENSE for more details.
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/decorator.py?line=10'>11</a> """
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/decorator.py?line=11'>12</a> from functools import update_wrapper
# ---> <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/decorator.py?line=12'>13</a> from flask import make_response, request, current_app
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/decorator.py?line=13'>14</a> from .core import *
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask_cors/decorator.py?line=15'>16</a> LOG = logging.getLogger(__name__)
#
# File ~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask/__init__.py:19, in <module>
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask/__init__.py?line=15'>16</a> from werkzeug.exceptions import abort
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask/__init__.py?line=16'>17</a> from werkzeug.utils import redirect
# ---> <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask/__init__.py?line=18'>19</a> from . import json
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask/__init__.py?line=19'>20</a> from ._compat import json_available
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask/__init__.py?line=20'>21</a> from .app import Flask
#
# File ~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask/json/__init__.py:15, in <module>
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask/json/__init__.py?line=11'>12</a> from datetime import date
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask/json/__init__.py?line=12'>13</a> from datetime import datetime
# ---> <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask/json/__init__.py?line=14'>15</a> from itsdangerous import json as _json
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask/json/__init__.py?line=15'>16</a> from jinja2 import Markup
#      <a href='file:///~/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/flask/json/__init__.py?line=16'>17</a> from werkzeug.http import http_date
#
# ImportError: cannot import name 'json' from 'itsdangerous' (/home/zavlyanova/Documents/00projects/Fil_rouge/fil-rouge/filerougevenv/lib/python3.8/site-packages/itsdangerous/__init__.py)
